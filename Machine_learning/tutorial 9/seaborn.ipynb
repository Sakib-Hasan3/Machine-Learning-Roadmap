# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import matplotlib.pyplot as plt
sns.displot(tips["total_bill"], kde=True);
plt.show()

# %%
sns.displot(tips["total_bill"], kde=True,bins=30);
plt.show()

# %%
sns.histplot(tips["total_bill"], kde=True, bins=30);
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde");
plt.show()

# %%
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips,hue='smoker')
plt.show()

# %%
sns.rugplot(tips["total_bill"]);
plt.show()

# %%
sns.displot(tips, x="total_bill", y="tip", hue="smoker", kind="kde")
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="day", y="total_bill", data=tips, palette="Blues",estimator=sum)
plt.show()
# Out:
# C:\Users\Pacific BD\AppData\Local\Temp\ipykernel_2364\1714628628.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="day", y="total_bill", data=tips, palette="Blues",estimator=sum)

# %%
import seaborn as sns
import matplotlib.pyplot as plt  
tips = sns.load_dataset("tips")
sns.boxplot(x="day", y="total_bill", data=tips, palette="Blues",hue='smoker')
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips, palette="Blues",hue='smoker',split=True)
plt.show()

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, palette="Blues",hue='smoker')
plt.show()

# %% [markdown]
# # Stripplot

# %%
sns.stripplot(x="day", y="total_bill", data=tips, palette="Blues",hue='smoker',dodge=True, jitter=True)
plt.show()

# %% [markdown]
# # Catplot

# %%
sns.catplot(x="day", y="total_bill", data=tips, palette="Blues",hue='smoker', kind='box')
plt.show()

# %% [markdown]
# # Matrix plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette="Blues",hue='smoker', dodge=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tc= tips.corr(numeric_only=True)
print(tc)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
flights=sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fp = flights.pivot_table(index='month', columns='year', values='passengers')
print(fp.shape)
print(fp.head())
# Out:
# (12, 12)
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# C:\Users\Pacific BD\AppData\Local\Temp\ipykernel_9460\3066324756.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(fp, cmap='plasma', linewidth=0.5, annot=True, fmt=".0f")
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp,cmap='plasma')

# %% [markdown]
# # gridplot

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df)

# %%
g=sns.PairGrid(df)
g.map_diag(sns.histplot)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.FacetGrid(tips,col='time',row='smoker')

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')
g.map(sns.scatterplot, 'total_bill','tip')

# %% [markdown]
# #

# %% [markdown]
# # Regression plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Lmplot

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='smoker',)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, row='sex',col='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex',row='time',hue='smoker')

# %% [markdown]
# # setplot

# %%
sns.set_style('whitegrid')
sns.countplot(data=tips,x='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(data=tips,x='smoker')
sns.despine()

# %% [markdown]
# # size and aspect

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill' , y='tip',aspect=4,data=tips)

# %% [markdown]
# # scale and context

# %%
sns.set_context("paper")
sns.countplot(x='sex',data=tips,palette='Blues')
# Out:
# C:\Users\Pacific BD\AppData\Local\Temp\ipykernel_9460\2065739687.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='Blues')
# <Axes: xlabel='sex', ylabel='count'>
