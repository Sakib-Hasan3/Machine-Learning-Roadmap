# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
#simple example 

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
# ploting using matplotlib

#plt scatter

plt.scatter(x,y,c='g')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Graph in 2D')
plt.show()
plt.savefig('test.png')
